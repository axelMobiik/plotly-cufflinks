# %% [markdown]
# <h1>Plotly and Cufflinks</h1>
# <li>Plotly is an interactive visualization library</li>
# <li>Cufflinks connects plotly with pandas</li>
# <li>Vefore we explore these libraries you'll need to install them</li>
# <li>You'll need to install it with pip at your command line or terminal with:</li>
#
# <code>pip install plotly</code>
# <code>pip install cufflinks</code>

# %%
import pandas as pd
import numpy as npb

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 5.22.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Data
df = pd.DataFrame(np.random.randn(100, 4), columns='A B C D'.split())
df.head()
# Out:
#           A         B         C         D
# 0  1.103244 -1.017505 -0.258333 -1.449097
# 1  0.278944  0.082467  0.080969  0.031884
# 2  1.321119 -0.837477 -0.034406 -1.156868
# 3 -0.491240  0.249960 -2.021583  1.708604
# 4 -1.460683 -0.141867 -0.341258 -0.837549

# %%
df2 = pd.DataFrame({'Category': ['A', 'B', 'C'], 'Values': [32, 43, 50]})
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.iplot()

# %%
df.iplot(kind='scatter', x='A', y='B', mode='markers')

# %%
df2.iplot(kind='bar', x='Category', y='Values')

# %%
df.iplot(kind='bar')

# %%
df.count().iplot(kind='bar')

# %%
df.sum().iplot(kind='bar')

# %%
df.iplot(kind='box')

# %%
df3 = pd.DataFrame({'x': [1,2,3,4,5], 'y': [10,20,30,20,10], 'z': [5,4,3,2,1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='surface')

# %%
df3.iplot(kind='surface', colorscale='rdylbu')

# %%
df['A'].iplot(kind='hist')

# %%
df['A'].iplot(kind='hist', bins=50)

# %%
df.iplot(kind='hist')

# %%
# df[['A', 'B']].iplot(kind='spread')

# Solve the problem with: https://stackoverflow.com/questions/76459499/attributeerror-module-pandas-has-no-attribute-np-cufflinks-spread-graph

# %%
df.iplot(kind='bubble', x='A', y='B', size='C')

# %%
df.scatter_matrix()
